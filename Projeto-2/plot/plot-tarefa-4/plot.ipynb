# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Caminho para o arquivo
caminho = '/home/jvloliveira/root/Graduação/Semestre 2 - 2025/IntroFiscomp/Projeto-2/tarefa-4/saida-1-12694394.txt'
caminho1 = '/home/jvloliveira/root/Graduação/Semestre 2 - 2025/IntroFiscomp/Projeto-2/tarefa-4/saida-2-12694394.txt'

# Carregar o arquivo CSV
df = pd.read_csv(caminho, sep=',', header=None)
df1 = pd.read_csv(caminho1, sep=',', header=None)
# Dados
xdata = df[0].values
ydata = df[1].values

# Dados
xdata1 = df1[0].values
ydata1 = df1[1].values

# Gráfico
plt.figure(figsize=(12,6))
plt.plot(xdata, ydata, label='m = 1000', color='blue')
plt.plot(xdata1, ydata1, label='m = 2000', color='red')
plt.xlabel("Número de passos")
plt.ylabel("Entropia")
# plt.legend()
plt.savefig("tarefa-4-graf-2.png", format='png', dpi=600)
plt.show()
