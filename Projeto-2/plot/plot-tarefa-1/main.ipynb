# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
caminho = '/home/jvloliveira/root/Graduação/Semestre 2 - 2025/IntroFiscomp/Projeto-2/tarefa-1/saida-1-12694394.txt'
df = pd.read_csv(caminho,header=None)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dados de exemplo

# Histograma vertical tradicional
plt.figure(figsize=(12, 5))


plt.hist(df)
plt.tight_layout()
plt.show()
